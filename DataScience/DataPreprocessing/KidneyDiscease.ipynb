# %%
import pandas as pd
dataset=pd.read_csv("kidney_disease.csv")

# %%
dataset
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
dataset.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
dataset.sort_values(by='age',ascending=True)
# Out:
#       id  age    bp     sg   al   su     rbc        pc         pcc  \
# 215  215  2.0   NaN  1.010  3.0  0.0  normal  abnormal  notpresent
# 187  187  3.0   NaN  1.010  2.0  0.0  normal    normal  notpresent
# 185  185  4.0   NaN  1.020  1.0  0.0     NaN    normal  notpresent
# 75    75  5.0   NaN  1.015  1.0  0.0     NaN    normal  notpresent
# 131  131  5.0  50.0  1.010  0.0  0.0     NaN    normal  notpresent
# ..   ...  ...   ...    ...  ...  ...     ...       ...         ...
# 117  117  NaN  70.0  1.020  0.0  0.0     NaN       NaN  notpresent
# 169  169  NaN  70.0  1.010  0.0  2.0     NaN    normal  notpresent
# 191  191  NaN  70.0  1.010  3.0  0.0  normal    normal  notpresent
# 203  203  NaN  90.0    NaN  NaN  NaN     NaN       NaN  notpresent
# 268  268  NaN  80.0    NaN  NaN  NaN     NaN       NaN  notpresent
#
#              ba  ...  pcv     wc   rc  htn   dm  cad appet   pe  ane  \
# 215  notpresent  ...  NaN    NaN  NaN   no   no   no  good  yes   no
# ...

# %%
medval=dataset["bu"].mean()
medval
# Out:
# 57.425721784776904

# %%
dataset["age"].fillna(medval,inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_25256\1620176330.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["age"].fillna(medval,inplace=True)

# %%
dataset
dataset.sort_values(by='age',ascending=True)
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 215  215   2.0   NaN  1.010  3.0  0.0  normal  abnormal  notpresent
# 187  187   3.0   NaN  1.010  2.0  0.0  normal    normal  notpresent
# 185  185   4.0   NaN  1.020  1.0  0.0     NaN    normal  notpresent
# 75    75   5.0   NaN  1.015  1.0  0.0     NaN    normal  notpresent
# 131  131   5.0  50.0  1.010  0.0  0.0     NaN    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 237  237  80.0  70.0  1.015  2.0  2.0     NaN    normal  notpresent
# 160  160  81.0  60.0    NaN  NaN  NaN     NaN       NaN  notpresent
# 39    39  82.0  80.0  1.010  2.0  2.0  normal       NaN  notpresent
# 171  171  83.0  70.0  1.020  3.0  0.0  normal    normal  notpresent
# 200  200  90.0  90.0  1.025  1.0  0.0     NaN    normal  notpresent
#
#              ba  ...  pcv     wc   rc  htn   dm  cad appet   pe  ane  \
# 215  notpresent  ...  NaN    NaN  NaN   no   no   no  good  yes   no
# ...

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        #print(columnName)
        if(dataset[columnName].dtype=='O'):
            #print("qual")
            qual.append(columnName)
        else:
            #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quan,qaul=quanQual(dataset)
dataset[quan]
# Out:
#       id   age    bp     sg   al   su    bgr    bu   sc    sod  pot  hemo
# 0      0  48.0  80.0  1.020  1.0  0.0  121.0  36.0  1.2    NaN  NaN  15.4
# 1      1   7.0  50.0  1.020  4.0  0.0    NaN  18.0  0.8    NaN  NaN  11.3
# 2      2  62.0  80.0  1.010  2.0  3.0  423.0  53.0  1.8    NaN  NaN   9.6
# 3      3  48.0  70.0  1.005  4.0  0.0  117.0  56.0  3.8  111.0  2.5  11.2
# 4      4  51.0  80.0  1.010  2.0  0.0  106.0  26.0  1.4    NaN  NaN  11.6
# ..   ...   ...   ...    ...  ...  ...    ...   ...  ...    ...  ...   ...
# 395  395  55.0  80.0  1.020  0.0  0.0  140.0  49.0  0.5  150.0  4.9  15.7
# 396  396  42.0  70.0  1.025  0.0  0.0   75.0  31.0  1.2  141.0  3.5  16.5
# 397  397  12.0  80.0  1.020  0.0  0.0  100.0  26.0  0.6  137.0  4.4  15.8
# 398  398  17.0  60.0  1.025  0.0  0.0  114.0  50.0  1.0  135.0  4.9  14.2
# 399  399  58.0  80.0  1.025  0.0  0.0  131.0  18.0  1.1  141.0  3.5  15.8
#
# [400 rows x 12 columns]

# %%
dataset.isnull().sum()
# Out:
# id                  0
# age                 0
# bp                  0
# sg                  0
# al                  0
# su                  0
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                 0
# bu                  0
# sc                  0
# sod                 0
# pot                 0
# hemo                0
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
dataset["age"].fillna(dataset["age"].median(),inplace=True)
dataset["bp"].fillna(dataset["bp"].median(),inplace=True)
dataset["sg"].fillna(dataset["sg"].median(),inplace=True)
dataset["al"].fillna(dataset["al"].median(),inplace=True)
dataset["su"].fillna(dataset["su"].median(),inplace=True)
dataset["bgr"].fillna(dataset["bgr"].median(),inplace=True)
dataset["bu"].fillna(dataset["bu"].median(),inplace=True)
dataset["sc"].fillna(dataset["sc"].median(),inplace=True)
dataset["sod"].fillna(dataset["sod"].median(),inplace=True)
dataset["pot"].fillna(dataset["pot"].median(),inplace=True)
dataset["hemo"].fillna(dataset["hemo"].median(),inplace=True)
dataset["pcv"].fillna(dataset["pcv"].median(),inplace=True)
dataset["wc"].fillna(dataset["wc"].median(),inplace=True)
dataset["rc"].fillna(dataset["rc"].median(),inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_25256\1280186820.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["age"].fillna(dataset["age"].median(),inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_25256\1280186820.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dataset
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
dataset[qaul]
# Out:
#         rbc        pc         pcc          ba pcv    wc   rc  htn   dm cad  \
# 0       NaN    normal  notpresent  notpresent  44  7800  5.2  yes  yes  no
# 1       NaN    normal  notpresent  notpresent  38  6000  NaN   no   no  no
# 2    normal    normal  notpresent  notpresent  31  7500  NaN   no  yes  no
# 3    normal  abnormal     present  notpresent  32  6700  3.9  yes   no  no
# 4    normal    normal  notpresent  notpresent  35  7300  4.6   no   no  no
# ..      ...       ...         ...         ...  ..   ...  ...  ...  ...  ..
# 395  normal    normal  notpresent  notpresent  47  6700  4.9   no   no  no
# 396  normal    normal  notpresent  notpresent  54  7800  6.2   no   no  no
# 397  normal    normal  notpresent  notpresent  49  6600  5.4   no   no  no
# 398  normal    normal  notpresent  notpresent  51  7200  5.9   no   no  no
# 399  normal    normal  notpresent  notpresent  53  6800  6.1   no   no  no
#
#     appet   pe  ane classification
# ...

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imp.fit(dataset[qaul])
df=imp.transform(dataset[qaul])
df = pd.DataFrame(df,columns = qaul)

# %%
df
# Out:
#         rbc        pc         pcc          ba pcv    wc   rc  htn   dm cad  \
# 0    normal    normal  notpresent  notpresent  44  7800  5.2  yes  yes  no
# 1    normal    normal  notpresent  notpresent  38  6000  5.2   no   no  no
# 2    normal    normal  notpresent  notpresent  31  7500  5.2   no  yes  no
# 3    normal  abnormal     present  notpresent  32  6700  3.9  yes   no  no
# 4    normal    normal  notpresent  notpresent  35  7300  4.6   no   no  no
# ..      ...       ...         ...         ...  ..   ...  ...  ...  ...  ..
# 395  normal    normal  notpresent  notpresent  47  6700  4.9   no   no  no
# 396  normal    normal  notpresent  notpresent  54  7800  6.2   no   no  no
# 397  normal    normal  notpresent  notpresent  49  6600  5.4   no   no  no
# 398  normal    normal  notpresent  notpresent  51  7200  5.9   no   no  no
# 399  normal    normal  notpresent  notpresent  53  6800  6.1   no   no  no
#
#     appet   pe  ane classification
# ...

# %%
dataset[quan]
# Out:
#       id   age    bp     sg   al   su         bgr    bu   sc         sod  pot  \
# 0      0  48.0  80.0  1.020  1.0  0.0  121.000000  36.0  1.2  137.528754  4.4
# 1      1   7.0  50.0  1.020  4.0  0.0  148.036517  18.0  0.8  137.528754  4.4
# 2      2  62.0  80.0  1.010  2.0  3.0  423.000000  53.0  1.8  137.528754  4.4
# 3      3  48.0  70.0  1.005  4.0  0.0  117.000000  56.0  3.8  111.000000  2.5
# 4      4  51.0  80.0  1.010  2.0  0.0  106.000000  26.0  1.4  137.528754  4.4
# ..   ...   ...   ...    ...  ...  ...         ...   ...  ...         ...  ...
# 395  395  55.0  80.0  1.020  0.0  0.0  140.000000  49.0  0.5  150.000000  4.9
# 396  396  42.0  70.0  1.025  0.0  0.0   75.000000  31.0  1.2  141.000000  3.5
# 397  397  12.0  80.0  1.020  0.0  0.0  100.000000  26.0  0.6  137.000000  4.4
# 398  398  17.0  60.0  1.025  0.0  0.0  114.000000  50.0  1.0  135.000000  4.9
# 399  399  58.0  80.0  1.025  0.0  0.0  131.000000  18.0  1.1  141.000000  3.5
#
#      hemo
# 0    15.4
# ...

# %%
combine=[dataset[quan],df]

# %%
combine
# Out:
# [      id   age    bp     sg   al   su         bgr    bu   sc         sod  pot  \
#  0      0  48.0  80.0  1.020  1.0  0.0  121.000000  36.0  1.2  137.528754  4.4
#  1      1   7.0  50.0  1.020  4.0  0.0  148.036517  18.0  0.8  137.528754  4.4
#  2      2  62.0  80.0  1.010  2.0  3.0  423.000000  53.0  1.8  137.528754  4.4
#  3      3  48.0  70.0  1.005  4.0  0.0  117.000000  56.0  3.8  111.000000  2.5
#  4      4  51.0  80.0  1.010  2.0  0.0  106.000000  26.0  1.4  137.528754  4.4
#  ..   ...   ...   ...    ...  ...  ...         ...   ...  ...         ...  ...
#  395  395  55.0  80.0  1.020  0.0  0.0  140.000000  49.0  0.5  150.000000  4.9
#  396  396  42.0  70.0  1.025  0.0  0.0   75.000000  31.0  1.2  141.000000  3.5
#  397  397  12.0  80.0  1.020  0.0  0.0  100.000000  26.0  0.6  137.000000  4.4
#  398  398  17.0  60.0  1.025  0.0  0.0  114.000000  50.0  1.0  135.000000  4.9
#  399  399  58.0  80.0  1.025  0.0  0.0  131.000000  18.0  1.1  141.000000  3.5
#
#       hemo
# ...

# %%
preprocessed=pd.concat(combine,axis=1)

# %%
preprocessed
# Out:
#       id   age    bp     sg   al   su         bgr    bu   sc         sod  ...  \
# 0      0  48.0  80.0  1.020  1.0  0.0  121.000000  36.0  1.2  137.528754  ...
# 1      1   7.0  50.0  1.020  4.0  0.0  148.036517  18.0  0.8  137.528754  ...
# 2      2  62.0  80.0  1.010  2.0  3.0  423.000000  53.0  1.8  137.528754  ...
# 3      3  48.0  70.0  1.005  4.0  0.0  117.000000  56.0  3.8  111.000000  ...
# 4      4  51.0  80.0  1.010  2.0  0.0  106.000000  26.0  1.4  137.528754  ...
# ..   ...   ...   ...    ...  ...  ...         ...   ...  ...         ...  ...
# 395  395  55.0  80.0  1.020  0.0  0.0  140.000000  49.0  0.5  150.000000  ...
# 396  396  42.0  70.0  1.025  0.0  0.0   75.000000  31.0  1.2  141.000000  ...
# 397  397  12.0  80.0  1.020  0.0  0.0  100.000000  26.0  0.6  137.000000  ...
# 398  398  17.0  60.0  1.025  0.0  0.0  114.000000  50.0  1.0  135.000000  ...
# 399  399  58.0  80.0  1.025  0.0  0.0  131.000000  18.0  1.1  141.000000  ...
#
# ...

# %%
preprocessed.isnull().sum()
# Out:
# id                0
# age               0
# bp                0
# sg                0
# al                0
# su                0
# bgr               0
# bu                0
# sc                0
# sod               0
# pot               0
# hemo              0
# rbc               0
# pc                0
# pcc               0
# ba                0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
preprocessed.to_csv("PreprocessChronicKidney.csv",index=False)
